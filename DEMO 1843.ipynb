# %%
print("hello world")
# Out:
# hello world

# %%
print('Hello world')
# Out:
# Hello world

# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# x=15
# print(x)

# %%
x=12
print(x)
# Out:
# 12

# %%
print("x= ",x)
# Out:
# x=  12

# %%
a = x+y
x=3
y=4
print(a)
# Out:
# 7

# %%
print(x)
# Out:
# 3
